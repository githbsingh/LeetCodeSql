# %% [markdown]
# <a href="https://colab.research.google.com/github/githbsingh/LeetCodeSql/blob/main/570_Managers_with_at_Least_5_Direct_Reports.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #### Q. 570. Managers with at Least 5 Direct Reports
# Sol. SELECT e1.name FROM Employee e1 INNER JOIN Employee e2
# ON e1.id=e2.managerId
# GROUP BY e1.id HAVING count(*) >=5

# %% [markdown]
# ![image.png](data:image/png;base64,...)
